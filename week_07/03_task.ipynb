# %% [markdown]
# ## Load and Preprocess a Small Image Dataset

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Load CIFAR-10 dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

print("Training images:", X_train.shape)
print("Training labels:", y_train.shape)

print("Testing images:", X_test.shape)
print("Testing labels:", y_test.shape)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 186s 1us/step
# Training images: (50000, 32, 32, 3)
# Training labels: (50000, 1)
# Testing images: (10000, 32, 32, 3)
# Testing labels: (10000, 1)

# %% [markdown]
# # Select a Small Dataset
#
# CIFAR-10 contains 50,000 training images, but the task asks for a small image dataset.
#
# We can use only 5,000 images:

# %%
X_train = X_train[:5000]
y_train = y_train[:5000]

X_test = X_test[:1000]
y_test = y_test[:1000]

print("Training images:", X_train.shape)
print("Testing images:", X_test.shape)
# Out:
# Training images: (5000, 32, 32, 3)
# Testing images: (1000, 32, 32, 3)

# %% [markdown]
# # Preprocess the data
# Preprocess the Images
#
# The original pixel values are between:
#
# 0 → 255
#
# For example:
#
# 0   = black
# 255 = maximum brightness
#
# Neural networks generally work better when the input values are scaled.
#
# We can convert them to:
#
# 0 → 1

# %%
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

# %%
# Define Class Names
# CIFAR-10 has 10 classes

class_names = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck"
]

# %% [markdown]
# # Visualize the Images
#
# Let's look at some images from our dataset.

# %%
plt.figure(figsize=(10, 5))

for i in range(10):

    plt.subplot(2, 5, i + 1)

    plt.imshow(X_train[i])

    plt.title(class_names[y_train[i][0]])

    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
#  Print one image information

print("Image shape:", X_train[0].shape)
print("Minimum pixel value:", X_train[0].min())
print("Maximum pixel value:", X_train[0].max())
print("First image class:", class_names[y_train[0][0]])
# Out:
# Image shape: (32, 32, 3)
# Minimum pixel value: 0.0
# Maximum pixel value: 0.003921569
# First image class: frog
