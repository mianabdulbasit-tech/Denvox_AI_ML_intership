# %% [markdown]
# # Week 1
# ## Mini Project:
# Student Grade Calculator
#
# ### **Objective:**
#
# Create a command-line application that:
#
# * Takes student information.
# * Takes marks as input.
# * Calculates percentage.
# * Assigns a grade.
# * Handles invalid input using try-except.
# * Continues until the user chooses to exit.

# %%
def take_marks(subject):
    try:
        marks = int(input(f"Enter the {subject} marks"))
        if 0<= marks <=100:
            return marks

        else:
            print("Enter the marks between the 0 and 100 ")

    except ValueError:
        print("please, Enter the number only")
    
    
def calculate_total(python, DataScience, AI):
    total_marks = python + DataScience + AI
    return total_marks
    
def calculate_percentage(percentage):
    marks_percentage = (total_marks/300) * 100
    return marks_percentage

def calculate_grade(percentage):
    if percentage >= 90:
        return "A+"

    elif percentage >=80:
        return "A"

    elif percentage >= 70:
        return "B"

    elif percentage >= 60:
        return "C"

    elif percentage >= 50:
        return "D"

    else:

        return "Fail"
  

def display_result(name, rollno, *subjects):
    print("\n-----------------------")
    print("------Student Repot------\n")

    print("Name :", name)
    print("RolL No", rollno)
    print("\n Marks")
    print("--------------------")
    print("Python :", python)
    print("Data Science : ", Datascience)
    print("AI : ", AI)

    print("--------------")
    print(f"Total : {total_marks} out of 300")
    print("Percentage : ", round(percentage, 2), "%")
    print("Grade : ", grade)
    if grade == "Fail":
        print("status : Fail")
    else:
        print("status : Pass")


while True:

    name = input("Enter the student name: ")
    rollno = input("Enter the roll no: ")

    python = take_marks("Python ")
    Datascience = take_marks("Data Science ")
    AI = take_marks("AI ")

    total_marks = calculate_total(
        python,
        Datascience,
        AI
    )
    percentage = calculate_percentage(total_marks)

    grade = calculate_grade(percentage)

    display_result(
        name,
        rollno,
        python,
        Datascience,
        AI,
        total_marks,
        percentage,
        grade
    )

    print("\nDo you want to calculate another student?")

    print("1. Yes")
    print("2. No")

    choice = input("Enter Choice : ")

    if choice == "2":
        print("\nProgram Closed Successfully.")
        break
# Out:
# -----------------------
# ------Student Repot------
#
# Name : basit
# RolL No 231048
#
#  Marks
# --------------------
# Python : 85
# Data Science :  77
# AI :  80
# --------------
# Total : 242 out of 300
# Percentage :  80.67 %
# Grade :  A
# status : Pass
#
# Do you want to calculate another student?
# 1. Yes
# 2. No
#
# -----------------------
# ------Student Repot------
#
# Name : mian
# RolL No 231148
#
#  Marks
# --------------------
# Python : 67
# Data Science :  79
# AI :  82
# --------------
# Total : 228 out of 300
# Percentage :  76.0 %
# Grade :  B
# status : Pass
#
# Do you want to calculate another student?
# 1. Yes
# 2. No
#
# Program Closed Successfully.
